# %%
import language_model as lgm
import tsne as ts
import numpy as np

# %%
md = lgm.train(16, 128)
# Out:
# Epoch 1
# Batch 100 Train CE 4.529
# Batch 200 Train CE 4.452
# Batch 300 Train CE 4.438
# Batch 400 Train CE 4.460
# Batch 500 Train CE 4.444
# Batch 600 Train CE 4.450
# Batch 700 Train CE 4.439
# Batch 800 Train CE 4.432
# Batch 900 Train CE 4.430
# Batch 1000 Train CE 4.411
# Running validation...
# Validation cross-entropy: 4.400
# Batch 1100 Train CE 4.386
# Batch 1200 Train CE 4.301
# Batch 1300 Train CE 4.232
# Batch 1400 Train CE 4.179
# Batch 1500 Train CE 4.107
# Batch 1600 Train CE 4.091
# Batch 1700 Train CE 4.024
# Batch 1800 Train CE 4.022
# Batch 1900 Train CE 3.990
# Batch 2000 Train CE 3.997
# Running validation...
# Validation cross-entropy: 3.970
# Batch 2100 Train CE 3.943
# Batch 2200 Train CE 3.909
# Batch 2300 Train CE 3.889
# Batch 2400 Train CE 3.800
# Batch 2500 Train CE 3.777
# Batch 2600 Train CE 3.775
# Batch 2700 Train CE 3.686
# Batch 2800 Train CE 3.658
# Batch 2900 Train CE 3.587
# Batch 3000 Train CE 3.555
# Running validation...
# ...

# %%
md.tsne_plot()
# Out:
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point  0  of  250 ...
# Mean value of sigma:  1.1294255403194156
# Iteration  10 : error is  13.829673282304636
# Iteration  20 : error is  13.262567767109545
# Iteration  30 : error is  14.27444202869068
# Iteration  40 : error is  14.621898628530085
# Iteration  50 : error is  13.946513767199512
# Iteration  60 : error is  13.434163551718674
# Iteration  70 : error is  13.866010727433398
# Iteration  80 : error is  13.692388146033588
# Iteration  90 : error is  13.324404272615373
# Iteration  100 : error is  13.732029107892263
# Iteration  110 : error is  1.778183552391069
# Iteration  120 : error is  1.3003435515079937
# Iteration  130 : error is  1.0955899020158608
# Iteration  140 : error is  1.0219309197421798
# Iteration  150 : error is  0.9569224201262672
# Iteration  160 : error is  0.9228869259196164
# Iteration  170 : error is  0.899358658435457
# ...
